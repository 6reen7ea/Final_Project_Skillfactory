# %% [markdown]
# # Сводный обзор всех датасетов проекта
#
# В этом ноутбуке приведены:
# - Описание каждого исходного датасета
# - Основные метаданные (объём, регионы, годы)
# - Ключевые признаки для мастер-таблицы
# - Комментарии по качеству данных
#
# Этот документ служит основой для формирования мастер-датасета и проведения анализа.

# %%
import pandas as pd

# %%
df = pd.read_excel("../../data/clean/datasets_overvieww.xlsx")
df
# Out:
#      №                Датасет                                    Файл  Строк  \
# 0    1                poverty                poverty_standardized.csv   2180
# 1    2                 income            real_income_standardized.csv    478
# 2    3                 socdem         poverty_socdem_standardized.csv    336
# 3    4              drug_alco              drug_alco_standardized.csv    696
# 4    5              morbidity              morbidity_standardized.csv  68041
# 5    6                housing                housing_standardized.csv     85
# 6    7                  gross                  gross_standardized.csv   2161
# 7    8             population             population_standardized.csv    505
# 8    9               disabled               disabled_standardized.csv   5434
# 9   10  child_mortality_rural  child_mortality_rural_standardized.csv   2674
# 10  11  child_mortality_urban  child_mortality_urban_standardized.csv   2705
# ...

# %% [markdown]
# ## Вывод
#
# После создания сводной таблицы по всем исходным наборам данных было  принято решение ограничиться
# периодом **2015–2020 гг.**, чтобы охватить последние доступные пять лет и при
# этом минимизировать разрывы в данных. Такой подход позволит сформировать единый
# мастер-датасет с полным набором показателей для всех регионов, что важно для
# корректного сравнения и кластеризации.
